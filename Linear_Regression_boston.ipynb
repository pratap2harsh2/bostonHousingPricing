# %%
import numpy as np
import pandas as pd

# %%
boston=pd.read_csv(r"BostonHousing.csv")

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# check the missing values
boston.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
boston.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x=boston['medv'],y=boston['crim'])
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.scatter(x=boston['rm'],y=boston['medv'])

# %%
import seaborn as sns 
sns.regplot(x='rm',y='medv',data=boston)
# Out:
# <AxesSubplot:xlabel='rm', ylabel='medv'>

# %%
sns.regplot(x='lstat',y='medv',data=boston)
# Out:
# <AxesSubplot:xlabel='lstat', ylabel='medv'>

# %%
sns.regplot(x='chas',y='medv',data=boston)
# Out:
# <AxesSubplot:xlabel='chas', ylabel='medv'>

# %%
# preparing independent and dependent features
X=boston.iloc[:,:-1]
Y=boston['medv']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([-0.58946835,  0.17933117,  0.39088283,  1.00568698, -1.49391244,
#         3.65787047, -0.9515434 , -2.20792408,  0.73320066, -0.28100285,
#        -2.28415304,  1.18619394, -2.47020722])

# %%
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([27.6044582 , 36.13782505, 17.69219527, 25.47225984, 18.5826659 ,
#        23.3452205 , 17.58616947, 15.67793578, 21.77080011, 20.28616494,
#        25.32342898, 19.12549622, -6.48945175, 22.74271293, 17.84417808,
#        26.48472147, 19.09439798,  5.08150302, 40.48665475, 17.20820455,
#        26.72800089, 29.08885824, 10.99940021, 23.83280829, 16.82307007,
#        14.1061069 , 23.2257152 , 14.77065842, 22.79843341, 18.91272099,
#        20.57964572, 24.69705617, 25.96499366, 15.42865053, 16.18306171,
#        17.50166879, 31.36415341, 19.05301647, 24.95146174, 25.58964026,
#        13.96666622, 29.66332405, 42.05665506, 17.7549447 , 26.57609443,
#        15.7422761 , 12.99546022, 26.96358183, 19.76386244, 29.76131623,
#        21.26359435, 33.98900314, 15.75891889, 25.97510358, 39.56977414,
#        22.70167518, 18.24047185, 30.86858554, 24.90516188, 12.73255908,
#        22.9305001 , 30.10185541, 31.10238678, 15.23660594, 21.80578338,
# ...

# %%
# plot a scatter plot for predicted values 
import matplotlib.pyplot as plt
plt.scatter(Y_test,reg_pred)

# %%
# plotting residual plot for this 
import seaborn as sns
residuals=Y_test-reg_pred
sns.displot(residuals,kind='kde')

# %%
## scatter plot prediction wrt reresiduals
## uniform distribution
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print(mean_absolute_error(Y_test,reg_pred))
print(mean_squared_error(Y_test,reg_pred))
# Out:
# 3.360380303331749
# 25.692433161205745

# %%
## R-square(coefficient of determination) and adjusted r-square values 
r-square=1-SSR/SST (sum of sqaures of residuals and total sum of squares)

adjusted r-square = 1-[(1-R2)(n-1)/(n-k-1)]  n: no of obervations k= predictor variables

# %%
from sklearn.metrics import r2_score
score=r2_score(Y_test,reg_pred)
print(score)
# Out:
# 0.7007474180149313

# %%
1-(1-score)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
# Out:
# 0.689338961810222

# %%
regression.predict(scaler.transform(boston.iloc[0:1,0:13]))
# Out:
# array([29.76131623])

# %%
boston.iloc[0:1,0:13]
# Out:
#       crim    zn  indus  chas    nox     rm   age   dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        b  lstat
# 0  396.9   4.98

# %%
## pickling the model file for deployment
import pickle 
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickel_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickel_model.predict(scaler.transform(boston.iloc[0:1,0:13]))
# Out:
# array([29.76131623])
